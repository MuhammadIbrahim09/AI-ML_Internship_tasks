# %% [markdown]
# House Price Prediction

# %% [markdown]
# **Task 6: House Price Prediction
# Objective:
# Predict house prices using property features such as size, bedrooms, and location.
# Dataset:
# House Price Prediction Dataset (available on Kaggle)
# Instructions:
# ● Perform preprocessing on features like square footage, number of bedrooms, and
# location.
# ● Train a regression model (Linear Regression or Gradient Boosting).
# ● Visualize predicted prices compared to actual prices.
# ● Evaluate with Mean Absolute Error (MAE) and RMSE.
# Skills:
# ● Regression modeling
# ● Feature scaling and selection
# ● Model evaluation (MAE, RMSE)
# ● Real estate data understanding**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("house_prices_dataset.csv")

# %%
dataset.head(50)
# Out:
#     square_feet  num_rooms  age  distance_to_city(km)          price
# 0   2248.357077          3   92             22.997972  200374.090410
# 1   1930.867849          2   22             13.984254  268784.847337
# 2   2323.844269          6   33             21.500945  315020.857676
# 3   2761.514928          3   63             10.343638  355111.468459
# 4   1882.923313          7   54             25.485200  234197.123903
# 5   1882.931522          2   70             16.510014  171397.001685
# 6   2789.606408          6    8             28.364627  438704.163041
# 7   2383.717365          5    3              3.285625  438745.704315
# 8   1765.262807          7   65             15.914028  243125.068444
# 9   2271.280022          3   90             23.227202  171466.048061
# 10  1768.291154          5   32             18.404427  266274.439215
# 11  1767.135123          4   31              1.672630  288522.028041
# 12  2120.981136          7   43             29.197822  282429.801192
# 13  1043.359878          7   36              9.649647  198661.919569
# 14  1137.541084          6   90              8.229058  134152.017207
# 15  1718.856235          6   91             15.084136  223511.745350
# 16  1493.584440          3   66             16.722585  121809.843049
# 17  2157.123666          7   59             23.222356  296965.282779
# 18  1545.987962          6   58             12.404936  241859.172792
# 19  1293.848149          4   35             13.758851  181208.272713
# 20  2732.824384          6   48             16.513838  393991.496180
# 21  1887.111850          7   50             12.437226  324604.319131
# 22  2033.764102          2    7             27.521894  182004.217313
# 23  1287.625907          5   49             25.686307   66630.545851
# 24  1727.808638          7   40             14.194237  302337.953337
# 25  2055.461295          4   37              1.005651  349602.749286
# 26  1424.503211          7   85             27.127100  120838.414961
# 27  2187.849009          4   77              4.605761  278725.492988
# 28  1699.680655          7   78              8.090860  235766.232076
# 29  1854.153125          5   54              5.418477  298065.449497
# 30  1699.146694          5   67              6.214652  289774.465750
# 31  2926.139092          4   17             24.283449  377732.472516
# 32  1993.251388          7   64             17.805542  278733.291369
# 33  1471.144536          5   63             28.726760  113550.524825
# 34  2411.272456          3   11              7.712152  415714.211359
# 35  1389.578175          7   40             15.083412  248057.749106
# 36  2104.431798          5   41             29.345423  209266.151074
# 37  1020.164938          2   59             24.966862    9752.509217
# 38  1335.906976          2   49             22.129855   87385.511083
# 39  2098.430618          3   80              6.480281  241236.411160
# 40  2369.233290          5   82             23.312757  272003.942815
# 41  2085.684141          2   35             11.079389  246099.502370
# 42  1942.175859          7   47             16.385570  272179.613402
# 43  1849.448152          6   70             18.665675  235611.518017
# 44  1260.739005          5   72             18.671548  122109.995362
# 45  1640.077896          3    7             22.069181  188645.342899
# 46  1769.680615          5   24             20.189361  225212.396392
# 47  2528.561113          4    6              2.982756  425868.137109
# 48  2171.809145          4    7             14.263064  350024.986162
# 49  1118.479922          2   87             20.256627   28310.567673

# %%
sns.scatterplot(x="square_feet",y="num_rooms",data=dataset,hue="price")
plt.show()

# %%
#dataset=dataset.iloc[:,:-1]

# %%
dataset.isnull().sum()
# Out:
# square_feet             0
# num_rooms               0
# age                     0
# distance_to_city(km)    0
# price                   0
# dtype: int64

# %%
x=dataset.iloc[:,:-1].values
x
# Out:
# array([[2.24835708e+03, 3.00000000e+00, 9.20000000e+01, 2.29979717e+01],
#        [1.93086785e+03, 2.00000000e+00, 2.20000000e+01, 1.39842538e+01],
#        [2.32384427e+03, 6.00000000e+00, 3.30000000e+01, 2.15009449e+01],
#        ...,
#        [1.64734164e+03, 5.00000000e+00, 8.00000000e+01, 2.18931243e+00],
#        [2.24788279e+03, 6.00000000e+00, 7.30000000e+01, 2.79310137e+01],
#        [2.32219423e+03, 7.00000000e+00, 7.30000000e+01, 1.05957213e+01]])

# %%
y=dataset.iloc[:,-1].values
print(y)
# Out:
# [200374.09041043 268784.84733716 315020.85767621 ... 233698.38430115
#  280766.82737854 342895.30911361]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# array([[2.10953578e+03, 5.00000000e+00, 1.00000000e+01, 1.81374012e+01],
#        [1.62639416e+03, 7.00000000e+00, 6.90000000e+01, 2.83455498e+01],
#        [1.88053395e+03, 7.00000000e+00, 2.00000000e+00, 1.57666942e+01],
#        ...,
#        [1.65029273e+03, 4.00000000e+00, 5.40000000e+01, 1.12632921e+01],
#        [2.10146151e+03, 2.00000000e+00, 3.50000000e+01, 3.25988685e+00],
#        [1.14116393e+03, 6.00000000e+00, 4.70000000e+01, 2.02262753e+00]])

# %% [markdown]
# **Using Gradient Boosting Regressor**

# %%
#from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,r2_score
#model=GradientBoostingRegressor(n_estimators=100,max_depth=10,learning_rate=0.1,random_state=42)
#model.fit(x_train,y_train)

# %%
#model.score(x_train,y_train)

# %%
#y_predict=model.predict(x_test)
#model.score(x_test,y_test)

# %%
#mae=mean_absolute_error(y_test,y_predict)
#r2=r2_score(y_test,y_predict)

# %%
#mae

# %%
#r2

# %% [markdown]
# **Using Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train),
model.score(x_train,y_train)
# Out:
# 0.9579283335680889

# %%
y_predict=model.predict(x_test)
model.score(x_test,y_test)
# Out:
# 0.9600636957617871

# %%
mae=mean_absolute_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)

# %%
mae
# Out:
# 15596.120539083615

# %%
r2
# Out:
# 0.9600636957617871

# %% [markdown]
# **Save Model**

# %%
import joblib
joblib.dump(model,"model.pkl")
# Out:
# ['model.pkl']
